# %% [markdown]
# ## Install dependencies

# %%
# !pip install -q \
    "langchain==0.3.25" \
    "langchain-core==0.3.62" \
    "langchain-text-splitters==0.3.8" \
    "langchain-google-genai==2.1.5" \
    "langchain-huggingface==0.1.2" \
    "chromadb>=1.0.9" \
    "rank-bm25==0.2.2" \
    "sentence-transformers>=2.6.0" \
    "gradio>=4.40,<6.0" \
    "gitpython>=3.1"



#"numpy>=1.22,<2.1" \
 #"langchain-chroma==0.2.4" \
# Out:
# ERROR: You must give at least one requirement to install (see "pip help install")

# %% [markdown]
# ## Configure Gemini API Key

# %%
## Setup api keys
import os

# Suppress ChromaDB telemetry warnings (harmless posthog SDK incompatibility)
os.environ["ANONYMIZED_TELEMETRY"] = "False"
os.environ["CHROMA_TELEMETRY_IMPL"] = "none"

try:
    from google.colab import userdata
    os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
    print("API key loaded from Colab secrets ✓")
except Exception:
    if "GOOGLE_API_KEY" not in os.environ:
        from getpass import getpass
        os.environ["GOOGLE_API_KEY"] = getpass("Paste your Gemini API key: ")
    print("API key set ✓")
# Out:
# API key set ✓

# %%
pip install "numpy>=2.1.0" "langchain-chroma==0.2.4"
# Out:
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (2.1.3)
# Collecting langchain-chroma==0.2.4
#   Using cached langchain_chroma-0.2.4-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: langchain-core>=0.3.60 in /usr/local/lib/python3.13/dist-packages (from langchain-chroma==0.2.4) (1.5.5)
# Collecting chromadb>=1.0.9 (from langchain-chroma==0.2.4)
#   Using cached chromadb-1.5.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting build>=1.0.3 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading build-1.5.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (2.13.4)
# Collecting pydantic-settings>=2.0 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pybase64>=1.4.1 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading pybase64-1.5.0-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma==0.2.4) (0.52.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (4.16.0)
# Collecting onnxruntime>=1.14.1 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading onnxruntime-1.29.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (1.42.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (4.67.3)
# Collecting overrides>=7.3.1 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (1.83.0)
# Collecting bcrypt>=4.0.1 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (0.27.1)
# Collecting kubernetes>=28.1.0 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading kubernetes-36.0.3-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (3.12.0)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.13/dist-packages (from chromadb>=1.0.9->langchain-chroma==0.2.4) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core>=0.3.60->langchain-chroma==0.2.4) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core>=0.3.60->langchain-chroma==0.2.4) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core>=0.3.60->langchain-chroma==0.2.4) (0.11.0)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core>=0.3.60->langchain-chroma==0.2.4) (26.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core>=0.3.60->langchain-chroma==0.2.4) (0.17.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.3.60->langchain-chroma==0.2.4) (3.1.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (2.32.4)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (2.5.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (3.14.3)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.60->langchain-chroma==0.2.4) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.60->langchain-chroma==0.2.4) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.60->langchain-chroma==0.2.4) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.60->langchain-chroma==0.2.4) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.60->langchain-chroma==0.2.4) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.60->langchain-chroma==0.2.4) (0.25.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma==0.2.4) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma==0.2.4) (5.29.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.13/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.75.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-semantic-conventions==0.65b0 (from opentelemetry-sdk>=1.2.0->chromadb>=1.0.9->langchain-chroma==0.2.4)
#   Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (0.4.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings>=2.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (2.21.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.13/dist-packages (from tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.27.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (0.0.5)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma==0.2.4) (8.4.2)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma==0.2.4) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma==0.2.4) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.24.5)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma==0.2.4) (3.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma==0.2.4) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma==0.2.4) (1.6.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (3.4.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma==0.2.4) (3.3.1)
# Downloading langchain_chroma-0.2.4-py3-none-any.whl (11 kB)
# Downloading chromadb-1.5.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 63.6 MB/s eta 0:00:00:00:0100:01
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 23.4 MB/s eta 0:00:00
# Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Downloading kubernetes-36.0.3-py2.py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 92.4 MB/s eta 0:00:00:00:01
# Downloading onnxruntime-1.29.0-cp313-cp313-manylinux_2_28_x86_64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 68.8 MB/s eta 0:00:00:00:0100:01
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.2 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 11.6 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.9 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 16.0 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.5.0-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.7/95.7 kB 10.0 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 6.2 MB/s eta 0:00:00
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.0 MB/s eta 0:00:00
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pypika, durationpy, pyproject_hooks, pybase64, overrides, opentelemetry-proto, opentelemetry-api, onnxruntime, importlib-resources, bcrypt, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, build, pydantic-settings, opentelemetry-sdk, kubernetes, opentelemetry-exporter-otlp-proto-grpc, chromadb, langchain-chroma
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.42.1
#     Uninstalling opentelemetry-api-1.42.1:
#       Successfully uninstalled opentelemetry-api-1.42.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.63b1
#     Uninstalling opentelemetry-semantic-conventions-0.63b1:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.63b1
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.42.1
#     Uninstalling opentelemetry-sdk-1.42.1:
#       Successfully uninstalled opentelemetry-sdk-1.42.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 2.7.1 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 2.7.1 requires opentelemetry-sdk<=1.42.1,>=1.39, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# Successfully installed bcrypt-5.0.0 build-1.5.0 chromadb-1.5.9 durationpy-0.10 importlib-resources-7.1.0 kubernetes-36.0.3 langchain-chroma-0.2.4 onnxruntime-1.29.0 opentelemetry-api-1.44.0 opentelemetry-exporter-otlp-proto-common-1.44.0 opentelemetry-exporter-otlp-proto-grpc-1.44.0 opentelemetry-proto-1.44.0 opentelemetry-sdk-1.44.0 opentelemetry-semantic-conventions-0.65b0 overrides-7.7.0 pybase64-1.5.0 pydantic-settings-2.15.0 pypika-0.51.1 pyproject_hooks-1.2.0

# %% [markdown]
# ## Temporary store git repo

# %%
#Import codebases from git
import shutil
from pathlib import Path
import git

# Change this to point at your own repo any time.
REPO_URL = "https://github.com/Priyabrata111/Ecommerce-App"
LOCAL_PATH = Path("/tmp/repo")

# Wipe any previous clone
if LOCAL_PATH.exists():
    shutil.rmtree(LOCAL_PATH)

git.Repo.clone_from(REPO_URL, LOCAL_PATH, depth=1)
print(f"Cloned into {LOCAL_PATH}")
print(f"Files: {sum(1 for _ in LOCAL_PATH.rglob('*') if _.is_file())}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3165/3063134464.py in <cell line: 0>()
#       2 import shutil
#       3 from pathlib import Path
# ----> 4 import git
#       5
#       6 # Change this to point at your own repo any time.
#
# ModuleNotFoundError: No module named 'git'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## View the Directory

# %%
def tree(p: Path, prefix: str = "", depth: int = 2) -> None:
    if depth < 0:
        return
    entries = sorted([e for e in p.iterdir() if not e.name.startswith(".")])
    for i, entry in enumerate(entries):
        is_last = i == len(entries) - 1
        connector = "└── " if is_last else "├── "
        print(prefix + connector + entry.name)
        if entry.is_dir():
            extension = "    " if is_last else "│   "
            tree(entry, prefix + extension, depth - 1)

tree(LOCAL_PATH)
# Out:
# ├── client
# │   └── build
# │       ├── asset-manifest.json
# │       ├── favicon.ico
# │       ├── images
# │       ├── index.html
# │       ├── logo192.png
# │       ├── logo512.png
# │       ├── manifest.json
# │       ├── robots.txt
# │       └── static
# ├── config
# │   └── db.js
# ├── controllers
# │   ├── authController.js
# │   ├── categoryController.js
# │   └── productController.js
# ├── helpers
# │   └── authHelper.js
# ├── middlewares
# │   └── authMiddleware.js
# ├── models
# │   ├── categoryModel.js
# │   ├── orderModel.js
# │   ├── productModel.js
# │   └── userModel.js
# ├── package-lock.json
# ├── package.json
# ├── routes
# │   ├── authRoute.js
# │   ├── categoryRoutes.js
# │   └── productRoutes.js
# └── server.js

# %% [markdown]
# ## Work with mutiple repos

# %%
REPOS = [
    {
        "name": "Ecommerce-App",
        "url": "https://github.com/Priyabrata111/Ecommerce-App"
    },
    {
        "name": "systemC",
        "url": "https://github.com/Priyabrata111/systemC"
    },
    {
        "name": "genAI_Learning",
        "url": "https://github.com/Priyabrata111/GenAI_Learning"
    },
    {
        "name": "Simon-Game",
        "url": "https://github.com/Priyabrata111/Simon-Game-Chellange"
    },
    {
        "name": "inotebook",
        "url": "https://github.com/Priyabrata111/inotebook"
    },
]

# %% [markdown]
# ## Import all Repos in local system

# %%
#Import codebases from git
import shutil
from pathlib import Path
import git


## Store here
ROOT_DIR = Path("/tmp/repos")

for repo in REPOS:
    repo_path = ROOT_DIR / repo["name"]

    if repo_path.exists():
        shutil.rmtree(repo_path)

    git.Repo.clone_from(
        repo["url"],
        repo_path,
        depth=1
    )

# %% [markdown]
# ## Check if repos are copied correctly

# %%
from pathlib import Path

for p in Path("/tmp/repos").iterdir():
    print(p)
    tree(p)
# Out:
# /tmp/repos/Simon-Game
# ├── game.js
# ├── index.html
# ├── sounds
# │   ├── blue.mp3
# │   ├── green.mp3
# │   ├── red.mp3
# │   ├── wrong.mp3
# │   └── yellow.mp3
# └── styles.css
# /tmp/repos/systemC
# ├── UST
# │   └── Basics
# │       ├── AT_tlm.cpp
# │       ├── event.cpp
# │       ├── handShake.cpp
# │       ├── interrupts_method.cpp
# │       ├── interrupts_thread.cpp
# │       ├── multiTransaction.cpp
# │       ├── producer_consumer.cpp
# │       ├── raceAround.cpp
# │       ├── tlm.cpp
# │       └── tlm2.cpp
# └── vConnect
#     ├── EthernetController
#     │   ├── EthernetFrame.h
#     │   ├── receiver.h
#     │   ├── target.h
#     │   ├── testBench.cpp
#     │   └── vECU.h
#     ├── LearningAll.cpp
#     ├── LearningBasics.cpp
#     ├── TLM
#     │   ├── LT.h
#     │   ├── Packet.h
#     │   ├── mainLT.cpp
#     │   ├── myCPU.h
#     │   ├── myCPUPacket.h
#     │   ├── myMemory.h
#     │   ├── myMemoryPacket.h
#     │   ├── testBench02.cpp
#     │   └── testbench.cpp
#     ├── designCounterMethod.cpp
#     └── designCounterThread.cpp
# /tmp/repos/genAI_Learning
# ├── Embeddings
# │   └── Embeddings.ipynb
# ├── FineTuning
# │   ├── FineTuning_LLM.ipynb
# │   ├── FineTuning_LLM_2.ipynb
# │   └── Quantization_Fine_Tuning.ipynb
# ├── FlaskAPIs
# │   ├── __pycache__
# │   │   ├── myFast.cpython-311.pyc
# │   │   ├── myModel.cpython-311.pyc
# │   │   ├── pydantic.cpython-311.pyc
# │   │   └── pydantic.cpython-313.pyc
# │   ├── myFast.py
# │   ├── myFlask.py
# │   └── myModel.py
# ├── Hugging Face
# │   └── Hugging_Face_Basics.ipynb
# ├── LangChain
# │   └── LangChain_hands_on.ipynb
# ├── RAG
# │   ├── RAG.ipynb
# │   ├── RAG_1.ipynb
# │   └── chroma_db
# │       ├── 24789017-658a-4203-8393-f8cb65424f08
# │       └── chroma.sqlite3
# └── RNN
#     └── RNN_Review_Classification.ipynb
# /tmp/repos/Ecommerce-App
# ├── client
# │   └── build
# │       ├── asset-manifest.json
# │       ├── favicon.ico
# │       ├── images
# │       ├── index.html
# │       ├── logo192.png
# │       ├── logo512.png
# │       ├── manifest.json
# │       ├── robots.txt
# │       └── static
# ├── config
# │   └── db.js
# ├── controllers
# │   ├── authController.js
# │   ├── categoryController.js
# │   └── productController.js
# ├── helpers
# │   └── authHelper.js
# ├── middlewares
# │   └── authMiddleware.js
# ├── models
# │   ├── categoryModel.js
# │   ├── orderModel.js
# │   ├── productModel.js
# │   └── userModel.js
# ├── package-lock.json
# ├── package.json
# ├── routes
# │   ├── authRoute.js
# │   ├── categoryRoutes.js
# │   └── productRoutes.js
# └── server.js
# /tmp/repos/inotebook
# ├── README.md
# ├── backend
# │   ├── db.js
# │   ├── index.js
# │   ├── middlewares
# │   │   └── fetchuser.js
# │   ├── models
# │   │   ├── Note.js
# │   │   └── User.js
# │   ├── package-lock.json
# │   ├── package.json
# │   └── routes
# │       ├── auth.js
# │       └── notes.js
# ├── package-lock.json
# ├── package.json
# ├── public
# │   └── index.html
# └── src
#     ├── App.css
#     ├── App.js
#     ├── components
#     │   ├── About.js
#     │   ├── AddNote.js
#     │   ├── Alert.js
#     │   ├── Home.js
#     │   ├── Login.js
#     │   ├── NavBar.js
#     │   ├── NoteItem.js
#     │   ├── Notes.js
#     │   └── Signup.js
#     ├── context
#     │   └── notes
#     ├── index.css
#     └── index.js

# %% [markdown]
# ## Load the repos as langchain documents

# %%
from pathlib import Path
from typing import List
import nbformat
from langchain_core.documents import Document
# Extensions relevant for MERN / Node.js / React
CODE_EXTENSIONS = {
      # C/C++
    ".c",
    ".cc",
    ".cpp",
    ".cxx",
    ".h",
    ".hh",
    ".hpp",
    ".hxx",

    # SystemC / TLM
    ".tpp",

    # Python
    ".py",
    ".ipynb",

    # JavaScript / TypeScript
    ".js",
    ".jsx",
    ".ts",
    ".tsx",

    # Config / Docs
    ".json",
    ".yaml",
    ".yml",
    ".xml",
    ".toml",
    ".ini",
    ".md",
    ".txt",

    # Web
    ".css",
    ".html",
}

# Folders to ignore
SKIP_DIRS = {
    ".git",
    "__pycache__",
    "node_modules",
    "dist",
    ".next",
    ".cache",
}
# Function to load the git repo as langchain model

def load_repo_documents(repo_path: Path,repo_name: str) -> List[Document]:
    docs = []

    for path in repo_path.rglob("*"):

        # Skip directories
        if not path.is_file():
            continue

        # Skip unwanted folders
        if any(part in SKIP_DIRS for part in path.parts):
            continue

        # Skip unsupported file types
        if path.suffix.lower() not in CODE_EXTENSIONS:
            continue

        try:
            # Special handling for Jupyter notebooks
            if path.suffix.lower() == ".ipynb":
                 nb = nbformat.read(path, as_version=4)

                 cells = []
                 # Keep only code + markdown content
                 for cell in nb.cells:
                     if cell.cell_type in ["code", "markdown"]:
                         cells.append(cell.source)
                  
           
                 text = "\n\n".join(cells)


            else:
                text = path.read_text(encoding="utf-8",errors="ignore")
        except UnicodeDecodeError:
            continue

        rel = path.relative_to(repo_path)

        docs.append(
            Document(
                page_content=text,
                metadata={
                "repo": repo_name,
                "source": str(rel),
                "extension": path.suffix,
},
            )
        )

    return docs


# Function call to load the repo as langchain documents
all_docs = []
for repo in REPOS:
    repo_path = ROOT_DIR / repo["name"]

    docs = load_repo_documents(
        repo_path,
        repo_name=repo["name"]
    )

    all_docs.extend(docs)

    print(f"Loaded {len(docs)} files from {repo['name']}")


print(f"\nTotal files loaded: {len(all_docs)}")

for d in all_docs[:10]:
    print(
        f"[{d.metadata['repo']}] "
        f"{d.metadata['source']:40s} "
        f"({len(d.page_content)} chars)"
    )
# Out:
# Loaded 24 files from Ecommerce-App
# Loaded 28 files from systemC
# Loaded 12 files from genAI_Learning
# Loaded 3 files from Simon-Game
# Loaded 28 files from inotebook
#
# Total files loaded: 95
# [Ecommerce-App] server.js                                (1440 chars)
# [Ecommerce-App] package-lock.json                        (135391 chars)
# [Ecommerce-App] package.json                             (854 chars)
# [Ecommerce-App] models/userModel.js                      (629 chars)
# [Ecommerce-App] models/productModel.js                   (697 chars)
# [Ecommerce-App] models/orderModel.js                     (496 chars)
# [Ecommerce-App] models/categoryModel.js                  (273 chars)
# [Ecommerce-App] middlewares/authMiddleware.js            (829 chars)
# [Ecommerce-App] controllers/authController.js            (6383 chars)
# [Ecommerce-App] controllers/categoryController.js        (2759 chars)

# %% [markdown]
# ## Perform smart chunking of the loaded docs

# %%
from langchain_text_splitters import (
    RecursiveCharacterTextSplitter,
    Language,
    MarkdownHeaderTextSplitter,
)

def chunk_smart(docs):

    py_splitter = RecursiveCharacterTextSplitter.from_language(
        language=Language.PYTHON,
        chunk_size=1500,
        chunk_overlap=150,
    )

    js_splitter = RecursiveCharacterTextSplitter.from_language(
        language=Language.JS,
        chunk_size=1500,
        chunk_overlap=150,
    )

    cpp_splitter = RecursiveCharacterTextSplitter.from_language(
        language=Language.CPP,
        chunk_size=1500,
        chunk_overlap=150,
    )

    md_splitter = MarkdownHeaderTextSplitter(
        headers_to_split_on=[
            ("#", "h1"),
            ("##", "h2"),
            ("###", "h3"),
        ],
        strip_headers=False,
    )

    fallback = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=100,
    )

    out = []

    for doc in docs:

        ext = doc.metadata.get("extension", "").lower()

        # Python
        if ext == ".py":
            for c in py_splitter.split_documents([doc]):
                c.metadata["chunk_type"] = "python"
                out.append(c)

        # Markdown
        elif ext == ".md":
            for c in md_splitter.split_text(doc.page_content):
                c.metadata = {
                    **doc.metadata,
                    **c.metadata,
                    "chunk_type": "markdown",
                }
                out.append(c)

        # JavaScript
        elif ext in [".js", ".jsx"]:
            for c in js_splitter.split_documents([doc]):
                c.metadata["chunk_type"] = "javascript"
                out.append(c)

        # TypeScript
        elif ext in [".ts", ".tsx"]:
            for c in js_splitter.split_documents([doc]):
                c.metadata["chunk_type"] = "typescript"
                out.append(c)

        # C / C++ / SystemC / TLM
        elif ext in [
            ".c",
            ".cc",
            ".cpp",
            ".cxx",
            ".h",
            ".hh",
            ".hpp",
            ".hxx",
        ]:
            for c in cpp_splitter.split_documents([doc]):
                c.metadata["chunk_type"] = "cpp"
                out.append(c)

        # Jupyter Notebook
        elif ext == ".ipynb":
            for c in fallback.split_documents([doc]):
                c.metadata["chunk_type"] = "notebook"
                out.append(c)

        # Everything else
        else:
            for c in fallback.split_documents([doc]):
                c.metadata["chunk_type"] = "text"
                out.append(c)

    return out



smart_chunks = chunk_smart(all_docs)

print(f"Created {len(smart_chunks)} chunks")

from collections import Counter

chunk_dist = Counter(
    c.metadata.get("chunk_type")
    for c in smart_chunks
)

print(f"By chunk type: {dict(chunk_dist)}")
# Out:
# Created 2146 chunks
# By chunk type: {'javascript': 1057, 'text': 964, 'cpp': 39, 'python': 3, 'notebook': 70, 'markdown': 13}

# %% [markdown]
# ## Store the chunks in chroma DB & store in Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

# Local embedding model
# Downloads once, then runs locally
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Quick smoke test
v = embeddings.embed_query("smoke test")
print(f"✓ Local embeddings loaded (vector dim = {len(v)})")


# Create Chroma vector database
vectorstore_v1 = Chroma.from_documents(
    documents=smart_chunks,
    embedding=embeddings,
    collection_name="multi_repo_v1",
    persist_directory="/content/drive/MyDrive/chroma_db",  # storing it in gDrive so that we can only use this db later
)

print(f"✓ Indexed {len(smart_chunks)} chunks")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ✓ Local embeddings loaded (vector dim = 384)
# ✓ Indexed 2146 chunks

# %%
# Later fetch the db from drive from here 
# vectorstore_v1= Chroma(
#     collection_name="multi_repo_v1",
#     persist_directory="/content/drive/MyDrive/chroma_db",
#     embedding_function=embeddings
# )

# %% [markdown]
# ##  Hybrid Search = semantic + BM25

# %%
# Build BM25 Index

from rank_bm25 import BM25Okapi
import re


def tokenize(text: str) -> list[str]:
    # Split on non-alphanumerics and lowercase. Keeps identifiers like 'JWTHandler' as one token.
    return [t.lower() for t in re.findall(r"\w+", text)]


# BM25 needs the tokenized chunks plus the original Document objects to return.
chunk_tokens = [tokenize(c.page_content) for c in smart_chunks]
bm25 = BM25Okapi(chunk_tokens)
print(f"BM25 ready over {len(smart_chunks)} chunks")
# Out:
# BM25 ready over 2146 chunks

# %% [markdown]
# ## Reciprocal Rank Fusion

# %%
def hybrid_search(query: str, k: int = 4, fetch_k: int = 12) -> list:
    # Semantic results (already ordered by similarity).
    semantic = vectorstore_v1.similarity_search(query, k=fetch_k)

    # BM25 results.
    bm25_scores = bm25.get_scores(tokenize(query))
    top_bm25_idx = sorted(range(len(bm25_scores)), key=lambda i: bm25_scores[i], reverse=True)[:fetch_k]
    keyword = [smart_chunks[i] for i in top_bm25_idx]

    # Reciprocal rank fusion — sum 1/(rank+60) across both lists.
    scores: dict[str, float] = {}
    docs_by_id: dict[str, object] = {}

    def doc_id(d):
        return f"{d.metadata.get('source','')}::{hash(d.page_content[:100])}"

    for rank, d in enumerate(semantic):
        did = doc_id(d)
        scores[did] = scores.get(did, 0) + 1 / (rank + 60)
        docs_by_id[did] = d
    for rank, d in enumerate(keyword):
        did = doc_id(d)
        scores[did] = scores.get(did, 0) + 1 / (rank + 60)
        docs_by_id[did] = d

    ranked = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:k]
    return [docs_by_id[did] for did, _ in ranked]


# Quick visual test
hits = hybrid_search("How Initiator makes a connection to target in TLM 2.0?", k=4)
for i, d in enumerate(hits, 1):
    print(f"{i}. {d.metadata['source']}")
# Out:
# 1. UST/Basics/AT_tlm.cpp
# 2. vConnect/TLM/myCPUPacket.h
# 3. UST/Basics/tlm.cpp
# 4. UST/Basics/multiTransaction.cpp

# %% [markdown]
# ## Cross encoder reranker

# %%
## Load the reranker

from sentence_transformers import CrossEncoder

reranker = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
print("Reranker loaded ✓")
# Out:
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# Reranker loaded ✓

# %%
def search_with_rerank(query: str, k: int = 4, fetch_k: int = 12) -> list:
    candidates = hybrid_search(query, k=fetch_k, fetch_k=fetch_k * 2)
    if not candidates:
        return []

    pairs = [(query, d.page_content) for d in candidates]
    scores = reranker.predict(pairs)

    ranked = sorted(zip(candidates, scores), key=lambda x: x[1], reverse=True)
    return [d for d, _ in ranked[:k]]

# %%
## Prompts & gemini
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

prompt = ChatPromptTemplate.from_template('''You are a helpful coding assistant answering questions about a codebase.
Use ONLY the context below. If the answer isn\'t in the context, say "I don\'t see that in the code."

Context:
{context}

Question: {question}

Answer:''')

def format_context(docs):
    return "\n\n---\n\n".join(
        f"# File: {d.metadata['source']}\n{d.page_content}" for d in docs
    )


def show_retrieval(question, docs):
    """Print which chunks were retrieved. Call before generation so students see retrieval as a step."""
    print(f"📚 Retrieved {len(docs)} chunks for: {question!r}")
    for i, d in enumerate(docs, 1):
        src = d.metadata.get("source", "?")
        size = len(d.page_content)
        line_info = ""
        if "start_line" in d.metadata:
            line_info = f":{d.metadata['start_line']}-{d.metadata['end_line']}"
        print(f"  {i}. {src}{line_info} ({size} chars)")
    print()

def ask_v1(question: str, k: int = 4) -> str:
    docs = search_with_rerank(question, k=k)
    show_retrieval(question, docs)
    chain = prompt | llm | StrOutputParser()
    return chain.invoke({"context": format_context(docs), "question": question})


print(ask_v1("How Initiator makes a connection to target in TLM 2.0?"))
# Out:
# 📚 Retrieved 4 chunks for: 'How Initiator makes a connection to target in TLM 2.0?'
#   1. UST/Basics/tlm.cpp (1495 chars)
#   2. UST/Basics/multiTransaction.cpp (1336 chars)
#   3. UST/Basics/tlm2.cpp (880 chars)
#   4. UST/Basics/AT_tlm.cpp (188 chars)
#
# In the provided code, an Initiator makes a connection to a Target using the `bind()` method.
#
# For example, in `UST/Basics/tlm.cpp`, the `sc_main` function shows:
# ```cpp
#   Initiator init("init");
#   Target tg("tg");
#
#   init.sc1.bind(tg.sc2);
# ```
# Here, `init.sc1` is the initiator's `tlm_utils::simple_initiator_socket` and `tg.sc2` is the target's `tlm_utils::simple_target_socket`.

# %% [markdown]
# ## Build an UI

# %%
import gradio as gr

def gradio_respond(message, history):
    return ask_v1(message)

demo = gr.ChatInterface(
    fn=gradio_respond,
    type="messages",
    title="Chat With Your Codebase",
    description="Chat with Priyabrata's repositories",
    examples=[
        "How Initiator makes a connection to target in TLM 2.0?",
        "How is b_transport implemented?",
        "Where is bcrypt used?",
        "How are JWT tokens generated and validated in ecommerce app?",
        "How does the simon game generate the next sequence?",
    ],
)

demo.launch(share=True, debug=False)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9df12205e55d19d1c3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9df12205e55d19d1c3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Check the chroma db stored in drive

# %%
from pathlib import Path

db = Path("/content/drive/MyDrive/chroma_db")

size_mb = sum(
    f.stat().st_size
    for f in db.rglob("*")
    if f.is_file()
) / (1024 * 1024)

print(f"{size_mb:.2f} MB")
# Out:
# 339.26 MB

# %% [markdown]
# ## Save b25

# %%
import pickle

with open("/content/drive/MyDrive/bm25.pkl", "wb") as f:
    pickle.dump(bm25, f)

# %% [markdown]
# ## also inclyde smart chunking in pkl file so that no need to clone the repo again and again

# %%
import pickle

with open("/content/drive/MyDrive/bm25_bundle.pkl", "wb") as f:
    pickle.dump(
        {
            "bm25": bm25,
            "chunks": smart_chunks
        },
        f
    )

print("Saved BM25 bundle")
# Out:
# Saved BM25 bundle

# %% [markdown]
# ## Save the reranker as well

# %%
reranker.save("/content/drive/MyDrive/reranker_model")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Debug

# %%
print("Collection:", vectorstore_v1._collection.name)
print("Count:", vectorstore_v1._collection.count())

docs = vectorstore_v1.similarity_search(
    "Where is the game-over condition implemented in the Simon Game?",
    k=5
)

print("\n=== RAW CHROMA ===")
for d in docs:
    print(d.metadata.get("source"))
# Out:
# Collection: multi_repo_v1
# Count: 34486
#
# === RAW CHROMA ===
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb

# %%
query = "Where is the game-over condition implemented in the Simon Game?"

scores = bm25.get_scores(tokenize(query))

top_idx = sorted(
    range(len(scores)),
    key=lambda i: scores[i],
    reverse=True
)[:10]

print("\n=== BM25 ===")

for i in top_idx:
    doc = smart_chunks[i]
    print(doc.metadata["source"])
# Out:
# === BM25 ===
# game.js
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# styles.css
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# index.html
# Hugging Face/Hugging_Face_Basics.ipynb

# %%
candidates = hybrid_search(query)

print("\n=== AFTER FUSION ===")

for i, d in enumerate(candidates[:20], 1):
    print(i, d.metadata["source"])
# Out:
# === AFTER FUSION ===
# 1 Hugging Face/Hugging_Face_Basics.ipynb
# 2 FineTuning/FineTuning_LLM_2.ipynb
# 3 game.js
# 4 Hugging Face/Hugging_Face_Basics.ipynb

# %%
pairs = [
    (query, d.page_content)
    for d in candidates
]

scores = reranker.predict(pairs)

ranked = sorted(
    zip(candidates, scores),
    key=lambda x: x[1],
    reverse=True
)

print("\n=== AFTER RERANK ===")

for doc, score in ranked[:10]:
    print(
        round(float(score), 4),
        doc.metadata["source"]
    )
# Out:
# === AFTER RERANK ===
# -7.6812 game.js
# -11.1468 FineTuning/FineTuning_LLM_2.ipynb
# -11.2357 Hugging Face/Hugging_Face_Basics.ipynb
# -11.3802 Hugging Face/Hugging_Face_Basics.ipynb

# %%
pairs = [
    (query, d.page_content)
    for d in candidates
]

scores = reranker.predict(pairs)

import numpy as np

print("NaN count:", np.isnan(scores).sum())

for doc, score in sorted(
    zip(candidates, scores),
    key=lambda x: x[1],
    reverse=True
)[:20]:
    print(score, doc.metadata["source"])
# Out:
# NaN count: 0
# -7.681178 game.js
# -11.146846 FineTuning/FineTuning_LLM_2.ipynb
# -11.235687 Hugging Face/Hugging_Face_Basics.ipynb
# -11.380157 Hugging Face/Hugging_Face_Basics.ipynb

# %%
import torch
import transformers
import sentence_transformers
import numpy as np

print("torch:", torch.__version__)
print("transformers:", transformers.__version__)
print("sentence-transformers:", sentence_transformers.__version__)
print("numpy:", np.__version__)
# Out:
# torch: 2.11.0+cpu
# transformers: 5.10.2
# sentence-transformers: 5.5.1
# numpy: 2.0.2

# %%
for c in smart_chunks:
    if c.metadata.get("extension") == ".ipynb":
        print("="*80)
        print(c.metadata["source"])
        print(c.page_content[:1000])
        break
# Out:
# ================================================================================
# Embeddings/Embeddings.ipynb
# !pip install -qU transformers sentence-transformers faiss-cpu
#
# from sentence_transformers import SentenceTransformer
# import numpy as np
# import faiss
#
# # 1. raw unstructured data
# sentences = [
#     "The Eiffel Tower stands tall in the heart of Paris, France.",
#     "I'm Priyabrata from West Bengal.",
#     "Coffee is one of the most widely consumed beverages in the world.",
#     "The sun rises in the east and sets in the west every single day.",
#     "I works at KPIT as SSE.",
#     "Subhendu Adhikari has been elected as the Chief Minister of West Bengal.",
#     "A balanced diet and regular exercise are key to maintaining good health.",
#     "I didn't get any increment this year either at KPIT.",
#     "Blockchain technology is revolutionizing the way financial transactions are recorded.",
#     "I have completed my masters from IIT Mandi in 2024.",
#     "The Indian Institute of Technology Mandi is a premier research university located in Kamand, Himachal Pradesh."
# ]
