# %% [markdown]
# ## Install dependencies

# %%
# !pip install -q \
    "numpy>=2.1.0,<3" \
    "langchain==0.3.25" \
    "langchain-core==0.3.62" \
    "langchain-text-splitters==0.3.8" \
    "langchain-google-genai==2.1.5" \
    "langchain-huggingface==0.1.2" \
    "langchain-chroma==0.2.4" \
    "chromadb>=1.0.9,<2" \
    "rank-bm25==0.2.2" \
    "sentence-transformers>=2.6,<4" \
    "gradio>=4.40,<6" \
    "gitpython>=3.1" \
    "nbformat>=5.10"

# %% [markdown]
# ## Configure Gemini API Key

# %%
## Setup api keys
import os

# Suppress ChromaDB telemetry warnings (harmless posthog SDK incompatibility)
os.environ["ANONYMIZED_TELEMETRY"] = "False"
os.environ["CHROMA_TELEMETRY_IMPL"] = "none"

try:
    from google.colab import userdata
    os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
    print("API key loaded from Colab secrets ✓")
except Exception:
    if "GOOGLE_API_KEY" not in os.environ:
        from getpass import getpass
        os.environ["GOOGLE_API_KEY"] = getpass("Paste your Gemini API key: ")
    print("API key set ✓")
# Out:
# API key set ✓

# %% [markdown]
# ## Temporary store git repo

# %%
#Import codebases from git
import shutil
from pathlib import Path
import git

# Change this to point at your own repo any time.
REPO_URL = "https://github.com/Priyabrata111/Ecommerce-App"
LOCAL_PATH = Path("/tmp/repo")

# Wipe any previous clone
if LOCAL_PATH.exists():
    shutil.rmtree(LOCAL_PATH)

git.Repo.clone_from(REPO_URL, LOCAL_PATH, depth=1)
print(f"Cloned into {LOCAL_PATH}")
print(f"Files: {sum(1 for _ in LOCAL_PATH.rglob('*') if _.is_file())}")
# Out:
# Cloned into /tmp/repo
# Files: 107

# %% [markdown]
# ## View the Directory

# %%
def tree(p: Path, prefix: str = "", depth: int = 2) -> None:
    if depth < 0:
        return
    entries = sorted([e for e in p.iterdir() if not e.name.startswith(".")])
    for i, entry in enumerate(entries):
        is_last = i == len(entries) - 1
        connector = "└── " if is_last else "├── "
        print(prefix + connector + entry.name)
        if entry.is_dir():
            extension = "    " if is_last else "│   "
            tree(entry, prefix + extension, depth - 1)

tree(LOCAL_PATH)
# Out:
# ├── client
# │   └── build
# │       ├── asset-manifest.json
# │       ├── favicon.ico
# │       ├── images
# │       ├── index.html
# │       ├── logo192.png
# │       ├── logo512.png
# │       ├── manifest.json
# │       ├── robots.txt
# │       └── static
# ├── config
# │   └── db.js
# ├── controllers
# │   ├── authController.js
# │   ├── categoryController.js
# │   └── productController.js
# ├── helpers
# │   └── authHelper.js
# ├── middlewares
# │   └── authMiddleware.js
# ├── models
# │   ├── categoryModel.js
# │   ├── orderModel.js
# │   ├── productModel.js
# │   └── userModel.js
# ├── package-lock.json
# ├── package.json
# ├── routes
# │   ├── authRoute.js
# │   ├── categoryRoutes.js
# │   └── productRoutes.js
# └── server.js

# %% [markdown]
# ## Work with mutiple repos

# %%
REPOS = [
    {
        "name": "Ecommerce-App",
        "url": "https://github.com/Priyabrata111/Ecommerce-App"
    },
    {
        "name": "systemC",
        "url": "https://github.com/Priyabrata111/systemC"
    },
    {
        "name": "genAI_Learning",
        "url": "https://github.com/Priyabrata111/GenAI_Learning"
    },
    {
        "name": "Simon-Game",
        "url": "https://github.com/Priyabrata111/Simon-Game-Chellange"
    },
    {
        "name": "inotebook",
        "url": "https://github.com/Priyabrata111/inotebook"
    },
]

# %% [markdown]
# ## Import all Repos in local system

# %%
#Import codebases from git
import shutil
from pathlib import Path
import git


## Store here
ROOT_DIR = Path("/tmp/repos")

repo_commits = {}

for repo in REPOS:
    repo_path = ROOT_DIR / repo["name"]

    if repo_path.exists():
        shutil.rmtree(repo_path)

    cloned_repo = git.Repo.clone_from(
        repo["url"],
        repo_path,
        depth=1
    )

    repo_commits[repo["name"]] = cloned_repo.head.commit.hexsha

    print(
        f"Cloned {repo['name']} at "
        f"{repo_commits[repo['name']][:8]}"
    )
# Out:
# Cloned Ecommerce-App at 7d48f477
# Cloned systemC at cbdf28a4
# Cloned genAI_Learning at 119158b8
# Cloned Simon-Game at d560dadb
# Cloned inotebook at b0d07153

# %% [markdown]
# ## Check if repos are copied correctly

# %%
from pathlib import Path

for p in Path("/tmp/repos").iterdir():
    print(p)
    tree(p)
# Out:
# /tmp/repos/genAI_Learning
# ├── Agentic_AI
# │   └── Agent1.ipynb
# ├── Embeddings
# │   └── Embeddings.ipynb
# ├── FineTuning
# │   ├── FineTuning_LLM.ipynb
# │   ├── FineTuning_LLM_2.ipynb
# │   └── Quantization_Fine_Tuning.ipynb
# ├── FlaskAPIs
# │   ├── __pycache__
# │   │   ├── myFast.cpython-311.pyc
# │   │   ├── myModel.cpython-311.pyc
# │   │   ├── pydantic.cpython-311.pyc
# │   │   └── pydantic.cpython-313.pyc
# │   ├── myFast.py
# │   ├── myFlask.py
# │   └── myModel.py
# ├── Hugging Face
# │   └── Hugging_Face_Basics.ipynb
# ├── LangChain
# │   └── LangChain_hands_on.ipynb
# ├── RAG
# │   ├── RAG.ipynb
# │   ├── RAG_1.ipynb
# │   └── chroma_db
# │       ├── 24789017-658a-4203-8393-f8cb65424f08
# │       └── chroma.sqlite3
# └── RNN
#     └── RNN_Review_Classification.ipynb
# /tmp/repos/inotebook
# ├── README.md
# ├── backend
# │   ├── db.js
# │   ├── index.js
# │   ├── middlewares
# │   │   └── fetchuser.js
# │   ├── models
# │   │   ├── Note.js
# │   │   └── User.js
# │   ├── package-lock.json
# │   ├── package.json
# │   └── routes
# │       ├── auth.js
# │       └── notes.js
# ├── package-lock.json
# ├── package.json
# ├── public
# │   └── index.html
# └── src
#     ├── App.css
#     ├── App.js
#     ├── components
#     │   ├── About.js
#     │   ├── AddNote.js
#     │   ├── Alert.js
#     │   ├── Home.js
#     │   ├── Login.js
#     │   ├── NavBar.js
#     │   ├── NoteItem.js
#     │   ├── Notes.js
#     │   └── Signup.js
#     ├── context
#     │   └── notes
#     ├── index.css
#     └── index.js
# /tmp/repos/Simon-Game
# ├── game.js
# ├── index.html
# ├── sounds
# │   ├── blue.mp3
# │   ├── green.mp3
# │   ├── red.mp3
# │   ├── wrong.mp3
# │   └── yellow.mp3
# └── styles.css
# /tmp/repos/Ecommerce-App
# ├── client
# │   └── build
# │       ├── asset-manifest.json
# │       ├── favicon.ico
# │       ├── images
# │       ├── index.html
# │       ├── logo192.png
# │       ├── logo512.png
# │       ├── manifest.json
# │       ├── robots.txt
# │       └── static
# ├── config
# │   └── db.js
# ├── controllers
# │   ├── authController.js
# │   ├── categoryController.js
# │   └── productController.js
# ├── helpers
# │   └── authHelper.js
# ├── middlewares
# │   └── authMiddleware.js
# ├── models
# │   ├── categoryModel.js
# │   ├── orderModel.js
# │   ├── productModel.js
# │   └── userModel.js
# ├── package-lock.json
# ├── package.json
# ├── routes
# │   ├── authRoute.js
# │   ├── categoryRoutes.js
# │   └── productRoutes.js
# └── server.js
# /tmp/repos/systemC
# ├── UST
# │   └── Basics
# │       ├── AT_tlm.cpp
# │       ├── event.cpp
# │       ├── handShake.cpp
# │       ├── interrupts_method.cpp
# │       ├── interrupts_thread.cpp
# │       ├── multiTransaction.cpp
# │       ├── producer_consumer.cpp
# │       ├── raceAround.cpp
# │       ├── tlm.cpp
# │       └── tlm2.cpp
# └── vConnect
#     ├── EthernetController
#     │   ├── EthernetFrame.h
#     │   ├── receiver.h
#     │   ├── target.h
#     │   ├── testBench.cpp
#     │   └── vECU.h
#     ├── LearningAll.cpp
#     ├── LearningBasics.cpp
#     ├── TLM
#     │   ├── LT.h
#     │   ├── Packet.h
#     │   ├── mainLT.cpp
#     │   ├── myCPU.h
#     │   ├── myCPUPacket.h
#     │   ├── myMemory.h
#     │   ├── myMemoryPacket.h
#     │   ├── testBench02.cpp
#     │   └── testbench.cpp
#     ├── designCounterMethod.cpp
#     └── designCounterThread.cpp

# %% [markdown]
# ## Load the repos as langchain documents

# %%
from pathlib import Path
from typing import List
import nbformat
from langchain_core.documents import Document
# Extensions relevant for MERN / Node.js / React
CODE_EXTENSIONS = {
      # C/C++
    ".c",
    ".cc",
    ".cpp",
    ".cxx",
    ".h",
    ".hh",
    ".hpp",
    ".hxx",

    # SystemC / TLM
    ".tpp",

    # Python
    ".py",
    ".ipynb",

    # JavaScript / TypeScript
    ".js",
    ".jsx",
    ".ts",
    ".tsx",

    # Config / Docs
    ".json",
    ".yaml",
    ".yml",
    ".xml",
    ".toml",
    ".ini",
    ".md",
    ".txt",

    # Web
    ".css",
    ".html",
}

# Folders to ignore
SKIP_DIRS = {
    ".git",
    "__pycache__",
    "node_modules",
    "dist",
    ".next",
    ".cache",
}
# Function to load the git repo as langchain model

def load_repo_documents(repo_path: Path,repo_name: str) -> List[Document]:
    docs = []

    for path in repo_path.rglob("*"):

        # Skip directories
        if not path.is_file():
            continue

        # Skip unwanted folders
        if any(part in SKIP_DIRS for part in path.parts):
            continue

        # Skip unsupported file types
        if path.suffix.lower() not in CODE_EXTENSIONS:
            continue

        try:
            # Special handling for Jupyter notebooks
            if path.suffix.lower() == ".ipynb":
                 nb = nbformat.read(path, as_version=4)

                 cells = []
                 # Keep only code + markdown content
                 for cell in nb.cells:
                     if cell.cell_type in ["code", "markdown"]:
                         cells.append(cell.source)
                  
           
                 text = "\n\n".join(cells)


            else:
                text = path.read_text(encoding="utf-8",errors="ignore")
        except UnicodeDecodeError:
            continue

        rel = path.relative_to(repo_path)
        repo_config = next(
            repo for repo in REPOS
            if repo["name"] == repo_name
            )

        docs.append(
            Document(
                page_content=text,
                metadata={
                "repo": repo_name,
                "repo_url": repo_config["url"],
                "commit_hash": repo_commits[repo_name],
                "source": str(rel),
                "extension": path.suffix.lower(),
                },
            )
        )

    return docs


# Function call to load the repo as langchain documents
all_docs = []
for repo in REPOS:
    repo_path = ROOT_DIR / repo["name"]

    docs = load_repo_documents(
        repo_path,
        repo_name=repo["name"]
    )

    all_docs.extend(docs)

    print(f"Loaded {len(docs)} files from {repo['name']}")


print(f"\nTotal files loaded: {len(all_docs)}")

for d in all_docs[:10]:
    print(
        f"[{d.metadata['repo']}] "
        f"{d.metadata['source']:40s} "
        f"({len(d.page_content)} chars)"
    )
# Out:
# Loaded 24 files from Ecommerce-App
# Loaded 28 files from systemC
# Loaded 13 files from genAI_Learning
# Loaded 3 files from Simon-Game
# Loaded 28 files from inotebook
#
# Total files loaded: 96
# [Ecommerce-App] package-lock.json                        (135391 chars)
# [Ecommerce-App] server.js                                (1440 chars)
# [Ecommerce-App] package.json                             (854 chars)
# [Ecommerce-App] routes/categoryRoutes.js                 (865 chars)
# [Ecommerce-App] routes/productRoutes.js                  (1837 chars)
# [Ecommerce-App] routes/authRoute.js                      (1344 chars)
# [Ecommerce-App] controllers/authController.js            (6383 chars)
# [Ecommerce-App] controllers/productController.js         (9609 chars)
# [Ecommerce-App] controllers/categoryController.js        (2759 chars)
# [Ecommerce-App] middlewares/authMiddleware.js            (829 chars)

# %% [markdown]
# ## Add Line numbers & stable chunk Ids

# %%
import hashlib


def add_chunk_metadata(original_doc, chunks):
    content = original_doc.page_content
    search_position = 0
    processed = []

    for chunk_index, chunk in enumerate(chunks):
        chunk_text = chunk.page_content

        start_index = content.find(
            chunk_text,
            search_position
        )

        if start_index == -1:
            start_index = content.find(chunk_text)

        if start_index == -1:
            start_index = 0

        end_index = start_index + len(chunk_text)

        start_line = content.count("\n", 0, start_index) + 1
        end_line = content.count("\n", 0, end_index) + 1

        repo = original_doc.metadata.get("repo", "")
        source = original_doc.metadata.get("source", "")

        raw_id = (
            f"{repo}:{source}:{start_line}:"
            f"{end_line}:{chunk_text}"
        )

        chunk_id = hashlib.sha256(
            raw_id.encode("utf-8")
        ).hexdigest()

        chunk.metadata.update({
            "chunk_id": chunk_id,
            "chunk_index": chunk_index,
            "start_line": start_line,
            "end_line": end_line,
        })

        processed.append(chunk)
        search_position = end_index

    return processed

# %% [markdown]
# ## Perform smart chunking of the loaded docs

# %%
from langchain_text_splitters import (
    RecursiveCharacterTextSplitter,
    Language,
    MarkdownHeaderTextSplitter,
)

def chunk_smart(docs):

    py_splitter = RecursiveCharacterTextSplitter.from_language(
        language=Language.PYTHON,
        chunk_size=1500,
        chunk_overlap=150,
    )

    js_splitter = RecursiveCharacterTextSplitter.from_language(
        language=Language.JS,
        chunk_size=1500,
        chunk_overlap=150,
    )

    cpp_splitter = RecursiveCharacterTextSplitter.from_language(
        language=Language.CPP,
        chunk_size=1500,
        chunk_overlap=150,
    )

    md_splitter = MarkdownHeaderTextSplitter(
        headers_to_split_on=[
            ("#", "h1"),
            ("##", "h2"),
            ("###", "h3"),
        ],
        strip_headers=False,
    )

    fallback = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=100,
    )

    out = []

    for doc in docs:

        ext = doc.metadata.get("extension", "").lower()

        # Python
        if ext == ".py":
            chunks = py_splitter.split_documents([doc])
            for c in chunks:
                c.metadata["chunk_type"] = "python"

            out.extend(add_chunk_metadata(doc, chunks))

        # Markdown
        elif ext == ".md":
            chunks = md_splitter.split_text(doc.page_content)
            for c in chunks:
                c.metadata = {

                    **doc.metadata,
                    **c.metadata,
                    "chunk_type": "markdown",
                }
            out.extend(add_chunk_metadata(doc, chunks))

        # JavaScript
        elif ext in [".js", ".jsx"]:
            chunks = js_splitter.split_documents([doc])
            for c in chunks:
                c.metadata["chunk_type"] = "javascript"
            out.extend(add_chunk_metadata(doc, chunks))

        # TypeScript
        elif ext in [".ts", ".tsx"]:
            chunks = js_splitter.split_documents([doc])
            for c in chunks:
                c.metadata["chunk_type"] = "typescript"
            out.extend(add_chunk_metadata(doc, chunks))

        # C / C++ / SystemC / TLM
        elif ext in [
            ".c",
            ".cc",
            ".cpp",
            ".cxx",
            ".h",
            ".hh",
            ".hpp",
            ".hxx",
        ]:
            chunks = cpp_splitter.split_documents([doc])
            for c in chunks:
                c.metadata["chunk_type"] = "cpp"
            out.extend(add_chunk_metadata(doc, chunks))

        # Jupyter Notebook
        elif ext == ".ipynb":
            chunks = fallback.split_documents([doc])
            for c in chunks:
                c.metadata["chunk_type"] = "notebook"
            out.extend(add_chunk_metadata(doc, chunks))

        # Everything else
        else:
            chunks = fallback.split_documents([doc])
            for c in chunks:
                c.metadata["chunk_type"] = "text"
            out.extend(add_chunk_metadata(doc, chunks))

    return out



smart_chunks = chunk_smart(all_docs)
print("Total chunks:", len(smart_chunks))

for c in smart_chunks[:10]:
    print({
        "repo": c.metadata.get("repo"),
        "source": c.metadata.get("source"),
        "type": c.metadata.get("chunk_type"),
        "start_line": c.metadata.get("start_line"),
        "end_line": c.metadata.get("end_line"),
        "chunk_id": c.metadata.get("chunk_id", "")[:12],
    })

print(f"Created {len(smart_chunks)} chunks")

from collections import Counter

chunk_dist = Counter(
    c.metadata.get("chunk_type")
    for c in smart_chunks
)

print(f"By chunk type: {dict(chunk_dist)}")
# Out:
# Total chunks: 2166
# {'repo': 'Ecommerce-App', 'source': 'package-lock.json', 'type': 'text', 'start_line': 1, 'end_line': 32, 'chunk_id': '9684730c15a8'}
# {'repo': 'Ecommerce-App', 'source': 'package-lock.json', 'type': 'text', 'start_line': 33, 'end_line': 52, 'chunk_id': 'cadf66bc697f'}
# {'repo': 'Ecommerce-App', 'source': 'package-lock.json', 'type': 'text', 'start_line': 51, 'end_line': 71, 'chunk_id': '18fccb4479e7'}
# {'repo': 'Ecommerce-App', 'source': 'package-lock.json', 'type': 'text', 'start_line': 71, 'end_line': 94, 'chunk_id': '7a8b542fe693'}
# {'repo': 'Ecommerce-App', 'source': 'package-lock.json', 'type': 'text', 'start_line': 93, 'end_line': 112, 'chunk_id': 'f2224ec14e92'}
# {'repo': 'Ecommerce-App', 'source': 'package-lock.json', 'type': 'text', 'start_line': 111, 'end_line': 131, 'chunk_id': '03c03caea2b6'}
# {'repo': 'Ecommerce-App', 'source': 'package-lock.json', 'type': 'text', 'start_line': 132, 'end_line': 150, 'chunk_id': '0c7f1d79c24b'}
# {'repo': 'Ecommerce-App', 'source': 'package-lock.json', 'type': 'text', 'start_line': 284, 'end_line': 303, 'chunk_id': 'b589e61e1ca7'}
# {'repo': 'Ecommerce-App', 'source': 'package-lock.json', 'type': 'text', 'start_line': 168, 'end_line': 190, 'chunk_id': '77ed6bd78595'}
# {'repo': 'Ecommerce-App', 'source': 'package-lock.json', 'type': 'text', 'start_line': 234, 'end_line': 253, 'chunk_id': '5cd8595e05de'}
# Created 2166 chunks
# By chunk type: {'text': 964, 'javascript': 1057, 'cpp': 39, 'notebook': 90, 'python': 3, 'markdown': 13}

# %% [markdown]
# ## Store the chunks in chroma DB & store in Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

# Local embedding model
# Downloads once, then runs locally
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Quick smoke test
v = embeddings.embed_query("smoke test")
print(f"✓ Local embeddings loaded (vector dim = {len(v)})")


# Create Chroma vector database
vectorstore_v1 = Chroma.from_documents(
    documents=smart_chunks,
    embedding=embeddings,
    collection_name="multi_repo_v1",
    persist_directory="/content/drive/MyDrive/chroma_db",  # storing it in gDrive so that we can only use this db later
)

print(f"✓ Indexed {len(smart_chunks)} chunks")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# ✓ Local embeddings loaded (vector dim = 384)
# ✓ Indexed 2166 chunks

# %%
# Later fetch the db from drive from here 
vectorstore_v1= Chroma(
     collection_name="multi_repo_v1",
     persist_directory="/content/drive/MyDrive/chroma_db",
     embedding_function=embeddings
 )

# %% [markdown]
# ##  Hybrid Search = semantic + BM25

# %%
# Build BM25 Index

from rank_bm25 import BM25Okapi
import re


def tokenize(text: str) -> list[str]:
    # Split on non-alphanumerics and lowercase. Keeps identifiers like 'JWTHandler' as one token.
    return [t.lower() for t in re.findall(r"\w+", text)]


# BM25 needs the tokenized chunks plus the original Document objects to return.
chunk_tokens = [tokenize(c.page_content) for c in smart_chunks]
bm25 = BM25Okapi(chunk_tokens)
print(f"BM25 ready over {len(smart_chunks)} chunks")
# Out:
# BM25 ready over 2166 chunks

# %% [markdown]
# ## Reciprocal Rank Fusion

# %%
def hybrid_search(query: str, k: int = 4, fetch_k: int = 12) -> list:
    # Semantic results (already ordered by similarity).
    semantic = vectorstore_v1.similarity_search(query, k=fetch_k)

    # BM25 results.
    bm25_scores = bm25.get_scores(tokenize(query))
    top_bm25_idx = sorted(range(len(bm25_scores)), key=lambda i: bm25_scores[i], reverse=True)[:fetch_k]
    keyword = [smart_chunks[i] for i in top_bm25_idx]

    # Reciprocal rank fusion — sum 1/(rank+60) across both lists.
    scores: dict[str, float] = {}
    docs_by_id: dict[str, object] = {}

    def doc_id(d):
        return f"{d.metadata.get('source','')}::{hash(d.page_content[:100])}"

    for rank, d in enumerate(semantic):
        did = doc_id(d)
        scores[did] = scores.get(did, 0) + 1 / (rank + 60)
        docs_by_id[did] = d
    for rank, d in enumerate(keyword):
        did = doc_id(d)
        scores[did] = scores.get(did, 0) + 1 / (rank + 60)
        docs_by_id[did] = d

    ranked = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:k]
    return [docs_by_id[did] for did, _ in ranked]


# Quick visual test
hits = hybrid_search("How Initiator makes a connection to target in TLM 2.0?", k=4)
for i, d in enumerate(hits, 1):
    print(f"{i}. {d.metadata['source']}")
# Out:
# 1. UST/Basics/AT_tlm.cpp
# 2. UST/Basics/tlm.cpp
# 3. UST/Basics/multiTransaction.cpp
# 4. UST/Basics/AT_tlm.cpp

# %% [markdown]
# ## Cross encoder reranker

# %%
## Load the reranker

from sentence_transformers import CrossEncoder

reranker = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
print("Reranker loaded ✓")
# Out:
# Reranker loaded ✓

# %%
def search_with_rerank(query: str, k: int = 4, fetch_k: int = 12) -> list:
    candidates = hybrid_search(query, k=fetch_k, fetch_k=fetch_k * 2)
    if not candidates:
        return []

    pairs = [(query, d.page_content) for d in candidates]
    scores = reranker.predict(pairs)

    ranked = sorted(zip(candidates, scores), key=lambda x: x[1], reverse=True)
    return [d for d, _ in ranked[:k]]

# %%
## Prompts & gemini
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

prompt = ChatPromptTemplate.from_template('''You are a helpful coding assistant answering questions about a codebase.
Use ONLY the context below. If the answer isn\'t in the context, say "I don\'t see that in the code."

Context:
{context}

Question: {question}

Answer:''')

def format_context(docs):
    return "\n\n---\n\n".join(
        f"# File: {d.metadata['source']}\n{d.page_content}" for d in docs
    )


def show_retrieval(question, docs):
    """Print which chunks were retrieved. Call before generation so students see retrieval as a step."""
    print(f"📚 Retrieved {len(docs)} chunks for: {question!r}")
    for i, d in enumerate(docs, 1):
        src = d.metadata.get("source", "?")
        size = len(d.page_content)
        line_info = ""
        if "start_line" in d.metadata:
            line_info = f":{d.metadata['start_line']}-{d.metadata['end_line']}"
        print(f"  {i}. {src}{line_info} ({size} chars)")
    print()

def ask_v1(question: str, k: int = 4) -> str:
    docs = search_with_rerank(question, k=k)
    show_retrieval(question, docs)
    chain = prompt | llm | StrOutputParser()
    return chain.invoke({"context": format_context(docs), "question": question})


print(ask_v1("How Initiator makes a connection to target in TLM 2.0?"))
# Out:
# 📚 Retrieved 4 chunks for: 'How Initiator makes a connection to target in TLM 2.0?'
#   1. UST/Basics/tlm.cpp:1-76 (1495 chars)
#   2. UST/Basics/multiTransaction.cpp:9-70 (1336 chars)
#   3. UST/Basics/tlm2.cpp:1-40 (880 chars)
#   4. UST/Basics/AT_tlm.cpp:1-8 (188 chars)
#
# In the provided code, an Initiator makes a connection to a Target using the `bind()` method.
#
# For example, in `UST/Basics/tlm.cpp`, the `sc_main` function shows:
# ```cpp
#   Initiator init("init");
#   Target tg("tg");
#
#   init.sc1.bind(tg.sc2);
# ```
# Here, `init.sc1` is the initiator's `tlm_utils::simple_initiator_socket` and `tg.sc2` is the target's `tlm_utils::simple_target_socket`.

# %% [markdown]
# ## Build an UI

# %%
import gradio as gr

def gradio_respond(message, history):
    return ask_v1(message)

demo = gr.ChatInterface(
    fn=gradio_respond,
    type="messages",
    title="Chat With Your Codebase",
    description="Chat with Priyabrata's repositories",
    examples=[
        "How Initiator makes a connection to target in TLM 2.0?",
        "How is b_transport implemented?",
        "Where is bcrypt used?",
        "How are JWT tokens generated and validated in ecommerce app?",
        "How does the simon game generate the next sequence?",
    ],
)

demo.launch(share=True, debug=False)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://dae4b21b12961c2e31.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://dae4b21b12961c2e31.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Check the chroma db stored in drive

# %%
from pathlib import Path

db = Path("/content/drive/MyDrive/chroma_db")

size_mb = sum(
    f.stat().st_size
    for f in db.rglob("*")
    if f.is_file()
) / (1024 * 1024)

print(f"{size_mb:.2f} MB")
# Out:
# 413.08 MB

# %% [markdown]
# ## Save b25

# %%
import pickle

with open("/content/drive/MyDrive/bm25.pkl", "wb") as f:
    pickle.dump(bm25, f)

# %% [markdown]
# ## also inclyde smart chunking in pkl file so that no need to clone the repo again and again

# %%
import pickle

with open("/content/drive/MyDrive/bm25_bundle.pkl", "wb") as f:
    pickle.dump(
        {
            "bm25": bm25,
            "chunks": smart_chunks
        },
        f
    )

print("Saved BM25 bundle")
# Out:
# Saved BM25 bundle

# %% [markdown]
# ## Save the reranker as well

# %%
reranker.save("/content/drive/MyDrive/reranker_model")

# %% [markdown]
# ## Debug

# %%
print("Collection:", vectorstore_v1._collection.name)
print("Count:", vectorstore_v1._collection.count())

docs = vectorstore_v1.similarity_search(
    "Where is the game-over condition implemented in the Simon Game?",
    k=5
)

print("\n=== RAW CHROMA ===")
for d in docs:
    print(d.metadata.get("source"))
# Out:
# Collection: multi_repo_v1
# Count: 40984
#
# === RAW CHROMA ===
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb

# %%
query = "Where is the game-over condition implemented in the Simon Game?"

scores = bm25.get_scores(tokenize(query))

top_idx = sorted(
    range(len(scores)),
    key=lambda i: scores[i],
    reverse=True
)[:10]

print("\n=== BM25 ===")

for i in top_idx:
    doc = smart_chunks[i]
    print(doc.metadata["source"])
# Out:
# === BM25 ===
# game.js
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# styles.css
# Hugging Face/Hugging_Face_Basics.ipynb
# index.html
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# Hugging Face/Hugging_Face_Basics.ipynb
# Agentic_AI/Agent1.ipynb

# %%
candidates = hybrid_search(query)

print("\n=== AFTER FUSION ===")

for i, d in enumerate(candidates[:20], 1):
    print(i, d.metadata["source"])
# Out:
# === AFTER FUSION ===
# 1 Hugging Face/Hugging_Face_Basics.ipynb
# 2 FineTuning/FineTuning_LLM_2.ipynb
# 3 game.js
# 4 Hugging Face/Hugging_Face_Basics.ipynb

# %%
pairs = [
    (query, d.page_content)
    for d in candidates
]

scores = reranker.predict(pairs)

ranked = sorted(
    zip(candidates, scores),
    key=lambda x: x[1],
    reverse=True
)

print("\n=== AFTER RERANK ===")

for doc, score in ranked[:10]:
    print(
        round(float(score), 4),
        doc.metadata["source"]
    )
# Out:
# === AFTER RERANK ===
# -7.6812 game.js
# -11.1468 FineTuning/FineTuning_LLM_2.ipynb
# -11.2357 Hugging Face/Hugging_Face_Basics.ipynb
# -11.3802 Hugging Face/Hugging_Face_Basics.ipynb

# %%
pairs = [
    (query, d.page_content)
    for d in candidates
]

scores = reranker.predict(pairs)

import numpy as np

print("NaN count:", np.isnan(scores).sum())

for doc, score in sorted(
    zip(candidates, scores),
    key=lambda x: x[1],
    reverse=True
)[:20]:
    print(score, doc.metadata["source"])
# Out:
# NaN count: 0
# -7.681178 game.js
# -11.146846 FineTuning/FineTuning_LLM_2.ipynb
# -11.235687 Hugging Face/Hugging_Face_Basics.ipynb
# -11.380157 Hugging Face/Hugging_Face_Basics.ipynb

# %%
import torch
import transformers
import sentence_transformers
import numpy as np

print("torch:", torch.__version__)
print("transformers:", transformers.__version__)
print("sentence-transformers:", sentence_transformers.__version__)
print("numpy:", np.__version__)
# Out:
# torch: 2.11.0+cpu
# transformers: 4.57.6
# sentence-transformers: 3.4.1
# numpy: 2.1.3

# %%
for c in smart_chunks:
    if c.metadata.get("extension") == ".ipynb":
        print("="*80)
        print(c.metadata["source"])
        print(c.page_content[:1000])
        break
# Out:
# ================================================================================
# Agentic_AI/Agent1.ipynb
# !pip install -q \
#     "langchain>=0.3" \
#     "langchain-core>=0.3" \
#     "langchain-google-genai>=2.0" \
#     "google-ai-generativelanguage>=0.6.10" \
#     "gradio>=4.40" \
#     "dotenv" \
#     "langchain-groq"
#
# from google.colab import drive
#
# drive.mount('/content/drive')
#
# ## set gemini key
# import os
# try:
#     from google.colab import userdata
#     os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")
#     print("API key loaded from Colab secrets ✓")
# except Exception:
#     if "GROQ_API_KEY" not in os.environ:
#         from getpass import getpass
#         os.environ["GROQ_API_KEY"] = getpass("Paste your GROQ_API_KEY API key: ")
#     print("API key set ✓")
#
# ## Setup the LLM
# # from langchain_google_genai import ChatGoogleGenerativeAI
#
# # llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)
# # print("Gemini 2.5 Flash ready")
# from langchain_groq import ChatGroq
#
# llm = ChatGroq(
#     model="openai/gpt-oss-20b",
#     temperature=0
# )
#
# ## Define the calculator tool

# %% [markdown]
# ## Implement Recall@K and MRR

# %%
import json


def normalize_path(path):
    return str(path).replace("\\", "/").lower()


def is_relevant(doc, test_case):
    actual_repo = doc.metadata.get("repo", "").lower()
    actual_file = normalize_path(
        doc.metadata.get("source", "")
    )

    expected_repo = test_case["expected_repo"].lower()
    expected_files = [
        normalize_path(path)
        for path in test_case["expected_files"]
    ]

    repo_matches = actual_repo == expected_repo

    file_matches = any(
        actual_file.endswith(expected_file)
        for expected_file in expected_files
    )

    return repo_matches and file_matches


def evaluate_retriever(search_function, test_cases, k=5):
    recall_hits = 0
    reciprocal_rank_sum = 0.0
    details = []

    for test_case in test_cases:
        results = search_function(
            test_case["question"],
            k=k
        )

        # Supports either Document or (Document, score).
        docs = [
            item[0] if isinstance(item, tuple) else item
            for item in results
        ]

        first_relevant_rank = None

        for rank, doc in enumerate(docs, start=1):
            if is_relevant(doc, test_case):
                first_relevant_rank = rank
                break

        hit = first_relevant_rank is not None

        if hit:
            recall_hits += 1
            reciprocal_rank_sum += (
                1.0 / first_relevant_rank
            )

        details.append({
            "id": test_case["id"],
            "hit": hit,
            "first_relevant_rank": first_relevant_rank,
            "retrieved": [
                {
                    "repo": doc.metadata.get("repo"),
                    "source": doc.metadata.get("source"),
                }
                for doc in docs
            ],
        })

    count = len(test_cases)

    return {
        f"recall@{k}": recall_hits / count,
        "mrr": reciprocal_rank_sum / count,
        "details": details,
    }

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'drive', '.gradio', 'sample_data']

# %% [markdown]
# ## Load Datasets

# %%
with open("/content/drive/MyDrive/evaluation_questions.json", encoding="utf-8") as file:
    test_cases = json.load(file)

print("Questions:", len(test_cases))
# Out:
# Questions: 30

# %% [markdown]
# ## Create three search wrappers:

# %%
def semantic_only(query, k=5):
    return vectorstore_v1.similarity_search(
        query,
        k=k
    )


def bm25_only(query, k=5):
    scores = bm25.get_scores(tokenize(query))

    indices = sorted(
        range(len(scores)),
        key=lambda i: scores[i],
        reverse=True
    )[:k]

    return [smart_chunks[i] for i in indices]


def hybrid_only(query, k=5):
    return hybrid_search(
        query,
        fetch_k=20
    )[:k]

# %% [markdown]
# ## Evaluate:

# %%
semantic_metrics = evaluate_retriever(
    semantic_only, test_cases, k=5
)

bm25_metrics = evaluate_retriever(
    bm25_only, test_cases, k=5
)

hybrid_metrics = evaluate_retriever(
    hybrid_only, test_cases, k=5
)

reranker_metrics = evaluate_retriever(
    search_with_rerank, test_cases, k=5
)

print("Semantic:", semantic_metrics["recall@5"], semantic_metrics["mrr"])
print("BM25:", bm25_metrics["recall@5"], bm25_metrics["mrr"])
print("Hybrid:", hybrid_metrics["recall@5"], hybrid_metrics["mrr"])
print("Reranked:", reranker_metrics["recall@5"], reranker_metrics["mrr"])
# Out:
# Semantic: 0.36666666666666664 0.36666666666666664
# BM25: 0.5333333333333333 0.40944444444444444
# Hybrid: 0.6 0.4638888888888889
# Reranked: 0.7 0.5722222222222222
